# %%
import pandas as pd

# Assuming you have your data frames stored in variables store_df, transaction_df, and product_df
store_df
transaction_df
product_df

# Drop rows with null values in each data frame
store_df_cleaned = store_df.dropna()
transaction_df_cleaned = transaction_df.dropna()
product_df_cleaned = product_df.dropna()

# Merge transaction and store data frames on STORE_NUM and STORE_ID
merged_df = pd.merge(transaction_df_cleaned, store_df_cleaned, left_on='STORE_NUM', right_on='STORE_ID')

# Merge the resulting data frame with the product data frame on UPC
final_df = pd.merge(merged_df, product_df_cleaned, on='UPC')

# Display the final combined data frame
print(final_df)

# %%
import pandas as pd
all_sheets = pd.read_excel('CollegeLife_Data_Challenge.xlsx', sheet_name=None)

# %%
for sheet_name, df in all_sheets.items():
    print(f"Sheet Name: {sheet_name}")
    print("\n")
# Out:
# Sheet Name: Glossary
#
#
# Sheet Name: Store Lookup
#
#
# Sheet Name: Products Lookup
#
#
# Sheet Name: Transaction Data

# %%
# Assuming you have your data frames stored in variables store_df, transaction_df, and product_df
store_df = all_sheets['Store Lookup']
product_df = all_sheets['Products Lookup']
transaction_df = all_sheets['Transaction Data']

# %%
transaction_df.head()
# Out:
#   WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS  SPEND  PRICE  \
# 0    2009-01-14        367  1111009477     13      13   13  18.07   1.39
# 1    2009-01-14        367  1111009497     20      18   18  27.80   1.39
# 2    2009-01-14        367  1111009507     14      14   14  19.32   1.38
# 3    2009-01-14        367  1111035398      4       3    3  14.00   3.50
# 4    2009-01-14        367  1111038078      3       3    3   7.50   2.50
#
#    BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY  Unnamed: 12  Unnamed: 13  \
# 0        1.57        0        0         1          NaN          NaN
# 1        1.39        0        0         0          NaN          NaN
# 2        1.38        0        0         0          NaN          NaN
# 3        4.49        0        0         1          NaN          NaN
# 4        2.50        0        0         0          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18
# ...

# %%
store_df.head()
# Out:
#    STORE_ID          STORE_NAME ADDRESS_CITY_NAME ADDRESS_STATE_PROV_CODE  \
# 0       389          SILVERLAKE          ERLANGER                      KY
# 1      2277  ANDERSON TOWNE CTR        CINCINNATI                      OH
# 2      4259       WARSAW AVENUE        CINCINNATI                      OH
# 3      6379            KINGWOOD          KINGWOOD                      TX
# 4      6431        AT WARD ROAD           BAYTOWN                      TX
#
#      MSA SEG_VALUE_NAME  PARKING_SPACE_QTY  SALES_AREA_SIZE_NUM  \
# 0  17140     MAINSTREAM              408.0                46073
# 1  17140        UPSCALE                NaN                81958
# 2  17140          VALUE                NaN                48813
# 3  26420     MAINSTREAM                NaN                50237
# 4  26420          VALUE              350.0                43698
#
#    AVG_WEEKLY_BASKETS   Latitude  Longitude
# 0        24766.807692  39.019940 -84.593645
# 1        54052.519231  39.058412 -84.339639
# ...

# %%
# Drop rows with null values in each data frame
# store_df_cleaned = store_df.dropna()
# transaction_df_cleaned = transaction_df.dropna()
# product_df_cleaned = product_df.dropna()

# Merge transaction and store data frames on STORE_NUM and STORE_ID
merged_df = pd.merge(transaction_df, store_df, left_on='STORE_NUM', right_on='STORE_ID')

# Merge the resulting data frame with the product data frame on UPC
final_df = pd.merge(merged_df, product_df, on='UPC')

# Display the final combined data frame
final_df.head()
# Out:
#   WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS  SPEND  PRICE  \
# 0    2009-01-14        367  1111009477     13      13   13  18.07   1.39
# 1    2009-01-21        367  1111009477     24      23   23  33.36   1.39
# 2    2009-01-28        367  1111009477      7       7    7   9.52   1.36
# 3    2009-02-04        367  1111009477     12      12   12  16.56   1.38
# 4    2009-02-11        367  1111009477     16      14   14  24.00   1.50
#
#    BASE_PRICE  FEATURE  ...  PARKING_SPACE_QTY  SALES_AREA_SIZE_NUM  \
# 0        1.57        0  ...              196.0                24721
# 1        1.57        0  ...              196.0                24721
# 2        1.36        0  ...              196.0                24721
# 3        1.38        0  ...              196.0                24721
# 4        1.50        0  ...              196.0                24721
#
#    AVG_WEEKLY_BASKETS  Latitude  Longitude             DESCRIPTION  \
# ...

# %%
final_df.to_excel('combined_data.xlsx', index=False)

# %%
final_df.shape
# Out:
# (538643, 35)

# %%
store_df.shape
# Out:
# (79, 11)

# %%
transaction_df.shape
# Out:
# (524950, 19)

# %%
product_df.shape
# Out:
# (58, 6)
